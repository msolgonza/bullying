# %% [markdown]
# ## Análisis de bullying en colegios secundarios de Argentina
#
# Se analiza un cuestionario autoadministrado de 72 preguntas a alumnos de entre 11 y 18 años de edad.
# Engloba los siguientes aspectos:
# - edad
# - género
# - alimentación
# - lesiones graves
# - intimidación
# - seguridad vial
# - amistades
# - tabaquismo
# - alcoholismo
# - drogas
# - sexualidad
# - actividad física
# - tiempo libre,
# - vinculo familiar

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
bullying = pd.read_csv("EMSE_DatosAbiertos.csv")

# %%
bullying.info
# Out:
# <bound method DataFrame.info of       sitio  record   q1 texto_q1   q2   texto_q2   q3  \
# 0        AG       1  3.0  13 años  2.0   Femenino  2.0
# 1        AG       2  3.0  13 años  2.0   Femenino  2.0
# 2        AG       3  4.0  14 años  1.0  Masculino  4.0
# 3        AG       4  6.0  16 años  1.0  Masculino  2.0
# 4        AG       5  3.0  13 años  2.0   Femenino  2.0
# ...     ...     ...  ...      ...  ...        ...  ...
# 56976    AG   57091  6.0  16 años  1.0  Masculino  5.0
# 56977    AG   57092  6.0  16 años  1.0  Masculino  5.0
# 56978    AG   57093  6.0  16 años  1.0  Masculino  NaN
# 56979    AG   57094  6.0  16 años  2.0   Femenino  5.0
# 56980    AG   57095  6.0  16 años  2.0   Femenino  5.0
#
#                                                 texto_q3    q4    q5  ...  \
# 0      9no grado nivel Primario/Polimodal o 2do año n...   NaN   NaN  ...
# 1      9no grado nivel Primario/Polimodal o 2do año n...   NaN   NaN  ...
# ...

# %%
bullying.describe()
# Out:
#              record            q1            q2            q3            q4  \
# count  56981.000000  56873.000000  56445.000000  55920.000000  36052.000000
# mean   28535.389832      4.905403      1.520188      3.064485      1.642857
# std    16479.971553      1.358115      0.499597      1.324451      0.096898
# min        1.000000      1.000000      1.000000      1.000000      1.200000
# 25%    14263.000000      4.000000      1.000000      2.000000      1.570000
# 50%    28522.000000      5.000000      2.000000      3.000000      1.640000
# 75%    42804.000000      6.000000      2.000000      4.000000      1.700000
# max    57095.000000      8.000000      2.000000      5.000000      2.030000
#
#                  q5            q6           q10           q15           q16  \
# count  36052.000000  56482.000000  56771.000000  56741.000000  56713.000000
# mean      60.212193      1.460448      1.802734      1.361573      1.496447
# ...

# %%
bullying.shape
# Out:
# (56981, 309)

# %%
cols=bullying.columns
print(cols)
# Out:
# Index(['sitio', 'record', 'q1', 'texto_q1', 'q2', 'texto_q2', 'q3', 'texto_q3',
#        'q4', 'q5',
#        ...
#        'texto_qnpa5g', 'qnpa7g', 'texto_qnpa7g', 'qnpe3g', 'texto_qnpe3g',
#        'qnpe5g', 'texto_qnpe5g', 'weight', 'stratum', 'psu'],
#       dtype='object', length=309)

# %%
for col in cols:
    print("La columna \"", col, "\" tiene valores: ", bullying[col].unique())
# Out:
# La columna " sitio " tiene valores:  ['AG']
# La columna " record " tiene valores:  [    1     2     3 ... 57093 57094 57095]
# La columna " q1 " tiene valores:  [ 3.  4.  6.  2.  5.  1.  7. nan  8.]
# La columna " texto_q1 " tiene valores:  ['13 años' '14 años' '16 años' '12 años' '15 años' '11 años o menos'
#  '17 años' nan '18 años o más']
# La columna " q2 " tiene valores:  [ 2.  1. nan]
# La columna " texto_q2 " tiene valores:  ['Femenino' 'Masculino' 'Dato perdido']
# La columna " q3 " tiene valores:  [ 2.  4. nan  3.  5.  1.]
# La columna " texto_q3 " tiene valores:  ['9no grado nivel Primario/Polimodal o 2do año nivel Secundario'
#  '2do año/11vo grado nivel Polimodal o 4to año nivel Secundario'
#  'Dato perdido'
#  '1er año/10mo grado nivel Polimodal o 3er año nivel Secundario'
#  '3er año/12vo grado nivel Polimodal o 5to año nivel Secundario'
#  '8vo grado nivel Primario/Polimodal  o 1er año nivel Secundario']
# ...

# %%
tabla = {"Columna":[],"Valores":[]}
print(tabla)
# Out:
# {'Columna': [], 'Valores': []}
